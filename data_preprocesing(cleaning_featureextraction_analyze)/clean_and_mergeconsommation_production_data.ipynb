# %%
import pandas as pd  # Data analysis and manipulation
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/prediction energy behavior of prosumer/data'

# %%
client = pd.read_csv(file_path + '/cleaned_client.csv')
consommation = pd.read_csv(file_path +'/consommation.csv')
electricity = pd.read_csv(file_path +'/electricity_prices.csv')
gas = pd.read_csv(file_path +'/gas_prices.csv')
weather = pd.read_csv(file_path +'/weather.csv')
prosumer= pd.read_csv(file_path +'/production.csv')

# %%
electricity= electricity.drop('origin_date', axis=1)

# %%
electricity.rename(columns={'forecast_date': 'datetime'}, inplace=True)

# %%
electricity
# Out:
#                   datetime  euros_per_mwh  data_block_id
# 0      2021-09-01 00:00:00          92.51              1
# 1      2021-09-01 01:00:00          88.90              1
# 2      2021-09-01 02:00:00          87.35              1
# 3      2021-09-01 03:00:00          86.88              1
# 4      2021-09-01 04:00:00          88.43              1
# ...                    ...            ...            ...
# 15281  2023-05-30 19:00:00          82.10            637
# 15282  2023-05-30 20:00:00         150.85            637
# 15283  2023-05-30 21:00:00          82.10            637
# 15284  2023-05-30 22:00:00          82.09            637
# 15285  2023-05-30 23:00:00          -1.29            637
#
# [15286 rows x 3 columns]

# %%
gas =gas.drop('origin_date', axis=1)
gas.rename(columns={'forecast_date': 'date'}, inplace=True)

# %%
gas
# Out:
#            date  lowest_price_per_mwh  highest_price_per_mwh  data_block_id
# 0    2021-09-01                 45.23                  46.32              1
# 1    2021-09-02                 45.62                  46.29              2
# 2    2021-09-03                 45.85                  46.40              3
# 3    2021-09-04                 46.30                  46.80              4
# 4    2021-09-05                 46.30                  46.58              5
# ..          ...                   ...                    ...            ...
# 632  2023-05-26                 29.10                  34.10            633
# 633  2023-05-27                 28.30                  34.10            634
# 634  2023-05-28                 28.10                  34.10            635
# 635  2023-05-29                 28.16                  36.98            636
# 636  2023-05-30                 29.00                  34.00            637
#
# [637 rows x 4 columns]

# %%
weather['data_block_id'] = weather['data_block_id'].astype(int)

# %%
weather
# Out:
#         Unnamed: 0             datetime  county  data_block_id  temperature  \
# 0                0  2021-09-01 00:00:00       0              1    13.600000
# 1                1  2021-09-01 00:00:00       1              1    14.000000
# 2                2  2021-09-01 00:00:00       2              1    12.000000
# 3                3  2021-09-01 00:00:00       3              1    11.533333
# 4                4  2021-09-01 00:00:00       4              1    11.666667
# ...            ...                  ...     ...            ...          ...
# 229120      229120  2023-05-30 10:00:00      10            637    13.150000
# 229121      229121  2023-05-30 10:00:00      11            637    13.325000
# 229122      229122  2023-05-30 10:00:00      13            637    14.000000
# 229123      229123  2023-05-30 10:00:00      14            637    14.000000
# 229124      229124  2023-05-30 10:00:00      15            637    13.880000
#
# ...

# %%
client['data_block_id'] = client['data_block_id']-1

# %%
client = client.drop('Unnamed: 0', axis=1)

# %%
prosumer =prosumer.drop('Unnamed: 0', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-040671b629a7> in <cell line: 1>()
# ----> 1 prosumer =prosumer.drop('Unnamed: 0', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
weather = weather.drop('Unnamed: 0', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-3d52db44db5c> in <cell line: 1>()
# ----> 1 weather = weather.drop('Unnamed: 0', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
prosumer['data_block_id'] = prosumer['data_block_id']+1

# %%
output = pd.merge(client, prosumer, on=['county', 'product_type', 'data_block_id','is_business'], how='inner')

# %%
weather = weather[weather['data_block_id'] <= 636]

# %%
prosumer = prosumer[prosumer['data_block_id'] <= 636]

# %%
gas = gas[gas['data_block_id'] <= 636]
electricity = electricity[electricity['data_block_id'] <= 636]

# %%
output = pd.merge(client, prosumer, on=['county', 'product_type', 'data_block_id','is_business'], how='inner')

# %%
output = pd.merge(output,weather, on=['county','datetime','data_block_id'], how='inner')

# %%
output.to_csv('./production_merge2.csv')

# %%
# prompt: I want remove the three coulumns ulnmed 0 , data_block_id, row_id, is_cunsummption

output = output.drop(['data_block_id', 'row_id', 'is_consumption'], axis=1)

# %%
output = pd.merge(output,gas, on=['data_block_id','date'], how='inner')

# %%
output = pd.merge(output,electricity,on=['data_block_id','datetime'], how='inner' )

# %%
output.drop('is_consumption', axis=1, inplace=True)

# %%
output
# Out:
#         product_type  county  eic_count  installed_capacity  is_business  \
# 0                  1       0        108              952.89            0
# 1                  2       0         17              166.40            0
# 2                  3       0        688             7207.88            0
# 3                  0       0          5              400.00            1
# 4                  1       0         43             1411.00            1
# ...              ...     ...        ...                 ...          ...
# 453977             1      15         51              415.60            0
# 453978             3      15        161             2035.75            0
# 453979             0      15         15              620.00            1
# 453980             1      15         20              624.50            1
# 453981             3      15         55             2188.20            1
#
#               date    target             datetime  prediction_unit_id  \
# ...

# %%
# Convert data_block_id to the same data type to ensure matching works correctly
output['data_block_id'] = output['data_block_id'].astype(float)
weather['data_block_id'] = weather['data_block_id'].astype(float)

# Initialize an empty list to hold merged data
merged_data = []

# Loop through each row in the production dataframe
for idx, prod_row in output.iterrows():
    # Find matching row in weather dataframe based on data_block_id
    match = weather[weather['data_block_id'] == prod_row['data_block_id']]

    # If there's a match, merge the two rows
    if not match.empty:
        for _, weather_row in match.iterrows():
            merged_row = {**prod_row.to_dict(), **weather_row.to_dict()}
            merged_data.append(merged_row)

# Convert the list of dictionaries to a dataframe
merged_df = pd.DataFrame(merged_data)

# Display the information of the merged dataframe
print(merged_df.info())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 15
#      13 # If there's a match, merge the two rows
#      14 if not match.empty:
# ---> 15     for _, weather_row in match.iterrows():
#      16         merged_row = {**prod_row.to_dict(), **weather_row.to_dict()}
#      17         merged_data.append(merged_row)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1453, in DataFrame.iterrows(self)
#    1451 using_cow = using_copy_on_write()
#    1452 for k, v in zip(self.index, self.values):
# -> 1453     s = klass(v, index=columns, name=k).__finalize__(self)
#    1454     if using_cow and self._mgr.is_single_block:
#    1455         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:521, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
# ...

# %%
output = pd.merge(output,electricity, on=['data_block_id'], how='inner')
